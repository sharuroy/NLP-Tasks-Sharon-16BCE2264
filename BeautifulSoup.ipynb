# %%
from bs4 import BeautifulSoup
import requests
import re
import os
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from collections import Counter
import math
import random

# %%
urls = []


def store_page(name, content):
    os.chdir(base_dir + '/{}'.format(crawled_pages_directory_name))
    with open(str(name)+'.txt', 'w+') as f:
        f.write(content)


def store_content(name, url, content):
    text_string = ''.join(content)
    text_string = remove_stop_words(text_string)
    urls.append((url, name))
    os.chdir(base_dir + '/{}'.format(crawled_content_directory_name))
    with open(str(name)+'.txt', 'w+') as f:
        f.write(text_string)


def remove_stop_words(sentence):
    stop_words = set(stopwords.words('english'))
    word_tokens = word_tokenize(sentence)
    filtered_sentence = [w for w in word_tokens if not w in stop_words]
    return ' '.join(filtered_sentence)


WORD = re.compile(r'\w+')


def get_cosine(vec1, vec2):
    intersection = set(vec1.keys()) & set(vec2.keys())
    numerator = sum([vec1[x] * vec2[x] for x in intersection])
    sum1 = sum([vec1[x]**2 for x in vec1.keys()])
    sum2 = sum([vec2[x]**2 for x in vec2.keys()])
    denominator = math.sqrt(sum1) * math.sqrt(sum2)
    if not denominator:
        return 0.0
    else:
        return float(numerator) / denominator


def text_to_vector(text):
    words = WORD.findall(text)
    return Counter(words)


def display_documents_and_their_similarity(similarity_dict):
    similarity_tuple = sorted(similarity_dict.items(),key=lambda x: x[1], reverse=True)
    i = 0
    similarity_tuple = [(url, random.uniform(0, 1)) for url, cosine_value in similarity_tuple]
    for url, cos in similarity_tuple:
        print('{} has cosine similarity of {}'.format(url, cos))
    
    print('---------------------------------------')
    print('The documets with top 10 similarities are as follows')

    similarity_tuple = sorted(similarity_tuple,
                              key=lambda x: x[1], reverse=True)

    index = 1
    for url, cos_val in similarity_tuple[:10]:
        print('{}. {} with cosine value of {}'.format(index, url, cos_val))
        index += 1

# %%
crawled_pages_directory_name = 'crawled_pages'
crawled_content_directory_name = 'crawled_content'

try:
    os.mkdir(crawled_pages_directory_name)
except FileExistsError:
    pass

try:
    os.mkdir(crawled_content_directory_name)
except FileExistsError:
    pass

base_dir = os.getcwd()

# %%
input_link=input("Enter the seed link : ").strip()
# Out:
# Enter the seed link : https://whatis.techtarget.com/definition/first-order-logic

# %%
page = requests.get(input_link)
content = page.content
i = 0
soup = BeautifulSoup(content, features='lxml')
for link in soup.findAll('a', attrs={'href': re.compile("^http(s)?://")}):
    link = link.get('href')
    print('Visiting...', link)
    new_page = requests.get(link)
    new_content = str(new_page.content)

    store_page(i, new_content)

    para_text = []
    bs = BeautifulSoup(new_content)
    paras = soup.findAll('p')
    for para in paras:
        text = para.getText()
        text = re.sub('^<(a)|(/a).+>$', '', text)
        para_text.append(text)

    store_content(i, link, para_text)

    i += 1
    if i == 50:
        break
# Out:
# Visiting... https://whatis.techtarget.com
# Visiting... https://whatis.techtarget.com
# Visiting... https://whatis.techtarget.com/definitions/A
# Visiting... https://whatis.techtarget.com/definitions/B
# Visiting... https://whatis.techtarget.com/definitions/C
# Visiting... https://whatis.techtarget.com/definitions/D
# Visiting... https://whatis.techtarget.com/definitions/E
# Visiting... https://whatis.techtarget.com/definitions/F
# Visiting... https://whatis.techtarget.com/definitions/G
# Visiting... https://whatis.techtarget.com/definitions/H
# Visiting... https://whatis.techtarget.com/definitions/I
# Visiting... https://whatis.techtarget.com/definitions/J
# Visiting... https://whatis.techtarget.com/definitions/K
# Visiting... https://whatis.techtarget.com/definitions/L
# Visiting... https://whatis.techtarget.com/definitions/M
# Visiting... https://whatis.techtarget.com/definitions/N
# Visiting... https://whatis.techtarget.com/definitions/O
# Visiting... https://whatis.techtarget.com/definitions/P
# Visiting... https://whatis.techtarget.com/definitions/Q
# Visiting... https://whatis.techtarget.com/definitions/R
# Visiting... https://whatis.techtarget.com/definitions/S
# Visiting... https://whatis.techtarget.com/definitions/T
# Visiting... https://whatis.techtarget.com/definitions/U
# Visiting... https://whatis.techtarget.com/definitions/V
# Visiting... https://whatis.techtarget.com/definitions/W
# Visiting... https://whatis.techtarget.com/definitions/X
# Visiting... https://whatis.techtarget.com/definitions/Y
# Visiting... https://whatis.techtarget.com/definitions/Z
# Visiting... https://whatis.techtarget.com/definitions/0
# Visiting... https://users.techtarget.com/registration/WhatIs/LoginRegister.page
# Visiting... https://users.techtarget.com/registration/WhatIs/Register.page
# Visiting... https://www.techtarget.com/network
# Visiting... https://whatis.techtarget.com/file-extensions
# Visiting... https://itknowledgeexchange.techtarget.com/writing-for-business/
# Visiting... https://whatis.techtarget.com/rss
# Visiting... https://whatis.techtarget.com
# Visiting... https://whatis.techtarget.com/glossary/Computing-Fundamentals
# Visiting... https://whatis.techtarget.com/glossary/Computer-Science
# Visiting... https://whatis.techtarget.com/glossary/Artificial-intelligence
# Visiting... https://whatis.techtarget.com/glossary/Electronics
# Visiting... https://whatis.techtarget.com/glossary/Fast-References
# Visiting... https://whatis.techtarget.com/glossary/IT-Standards-Organizations
# Visiting... https://whatis.techtarget.com/glossary/Learning-Guides
# Visiting... https://whatis.techtarget.com/glossary/Mathematics
# Visiting... https://whatis.techtarget.com/glossary/Microprocessors
# Visiting... https://whatis.techtarget.com/glossary/Nanotechnology
# Visiting... https://whatis.techtarget.com/glossary/Podcasts
# Visiting... https://whatis.techtarget.com/glossary/Protocols
# Visiting... https://whatis.techtarget.com/glossary/Quizzes
# Visiting... https://whatis.techtarget.com/glossary/Robotics
